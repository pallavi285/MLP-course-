# %% [markdown]
# ## Conversion to csv

# %%
df.to_csv('')

# %% [markdown]
# ## Sampling

# %% [markdown]
# ## sorting

# %%
import pandas as pd

# %%
df = pd.read_csv('Preprocessing1.csv')

# %%
df.head(5)
# Out:
#              Airline  Source Destination            Route Dep_Time  \
# 0        Jet Airways   Delhi    Banglore  DEL → BOM → COK    20:00
# 1        Jet Airways   Delhi      Cochin  DEL → BOM → COK    16:00
# 2        Jet Airways  Mumbai   Hyderabad        BOM → HYD    19:35
# 3  Multiple carriers   Delhi    Banglore  DEL → BOM → COK    18:55
# 4          Air India   Delhi      Cochin        DEL → COK    17:10
#
#    Arrival_Time Duration Total_Stops              Additional_Info  Price  \
# 0  04:25 10 Jun  26h 35m      1 stop  In-flight meal not included  14924
# 1  19:00 10 Jun      27h      1 stop  In-flight meal not included  10577
# 2         21:05   1h 30m    non-stop                      No info   5678
# 3  01:30 16 Jun  15h 10m      1 stop  In-flight meal not included   7408
# 4         17:55   8h 20m    non-stop                      No info   6724
#
#    Month   WeekDay   Day
# 0      6  Thursday   6.0
# 1      6    Sunday   9.0
# 2      3    Friday  15.0
# ...

# %%
df.sort_values(by = 'Price' , ascending = True).head(3)
# Out:
#        Airline  Source Destination      Route Dep_Time  Arrival_Time Duration  \
# 3715  SpiceJet  Mumbai      Cochin  BOM → HYD    10:45  00:10 22 Mar   4h 45m
# 6626  SpiceJet  Mumbai   Hyderabad  BOM → HYD    22:45  00:10 28 Mar   1h 25m
# 4548  SpiceJet  Mumbai      Cochin  BOM → HYD    12:30  00:15 02 Apr  20h 55m
#
#      Total_Stops Additional_Info  Price  Month    WeekDay   Day
# 3715    non-stop         No info   1759      3     Sunday   3.0
# 6626    non-stop         No info   1759      3  Wednesday  27.0
# 4548    non-stop         No info   1759      6   Saturday  15.0

# %%
df.sort_values(by = 'Duration' , ascending = True).head(3)
# Out:
#                 Airline    Source Destination            Route Dep_Time  \
# 8481           SpiceJet  Banglore      Cochin        BLR → DEL    09:00
# 4817  Multiple carriers     Delhi      Cochin  DEL → BOM → COK    09:00
# 3778          Air India     Delhi      Cochin  DEL → MAA → COK    09:15
#
#       Arrival_Time Duration Total_Stops Additional_Info  Price  Month  \
# 8481         23:20      10h    non-stop         No info   6860      6
# 4817         19:00      10h      1 stop         No info  10407      5
# 3778  09:25 07 May      10h      1 stop         No info   7480      5
#
#         WeekDay   Day
# 8481  Wednesday  12.0
# 4817     Monday   6.0
# 3778   Saturday  18.0

# %%
df.sort_values(by = 'Source' , ascending = True).tail(5)
# Out:
#           Airline  Source Destination      Route Dep_Time  Arrival_Time  \
# 7392  Jet Airways  Mumbai   Hyderabad  BOM → HYD    22:45         21:05
# 8344       IndiGo  Mumbai    Banglore  BOM → HYD    08:25         04:05
# 3111     SpiceJet  Mumbai      Cochin  BOM → HYD    06:05  00:15 28 May
# 3063     SpiceJet  Mumbai      Cochin  BOM → HYD    06:40         07:05
# 6993     SpiceJet  Mumbai   Hyderabad  BOM → HYD    13:15         14:45
#
#      Duration Total_Stops              Additional_Info  Price  Month  \
# 7392   1h 30m    non-stop                      No info   5678      6
# 8344  11h 25m    non-stop  In-flight meal not included   2754      6
# 3111  27h 20m    non-stop                      No info   1965      6
# 3063   9h 30m    non-stop                      No info   4391      3
# 6993   1h 30m    non-stop                      No info   2017      6
#
#        WeekDay   Day
# 7392    Monday   3.0
# 8344    Sunday   9.0
# 3111    Sunday   9.0
# 3063  Saturday   9.0
# ...

# %%
df.sort_values(by = ['Source','Destination','Price','Duration'] , ascending = True).head(20)
# Out:
#           Airline    Source Destination      Route Dep_Time  Arrival_Time  \
# 2150     SpiceJet  Banglore    Banglore  BLR → DEL    21:10         08:35
# 8068     Air Asia  Banglore    Banglore  BLR → DEL    19:00  02:10 22 Mar
# 7000       IndiGo  Banglore    Banglore  BLR → DEL    20:00  01:00 25 May
# 1120       IndiGo  Banglore    Banglore  BLR → DEL    18:55  01:00 02 Jun
# 8741        GoAir  Banglore    Banglore  BLR → DEL    17:00         23:40
# 6463        GoAir  Banglore    Banglore  BLR → DEL    22:50         23:40
# 7324       IndiGo  Banglore    Banglore  BLR → DEL    19:55         03:25
# 5418  Jet Airways  Banglore    Banglore  BLR → DEL    17:10         22:50
# 2906     SpiceJet  Banglore    Banglore  BLR → DEL    20:00  00:05 25 Apr
# 5610    Air India  Banglore    Banglore  BLR → DEL    17:00         08:55
# 8956       IndiGo  Banglore    Banglore  BLR → DEL    05:50  01:10 22 Mar
# 8330        GoAir  Banglore    Banglore  BLR → DEL    07:10         23:40
# ...

# %% [markdown]
# ## Dropping

# %%
x = df['Price']
x.head(6)
# Out:
# 0    14924
# 1    10577
# 2     5678
# 3     7408
# 4     6724
# 5    11087
# Name: Price, dtype: int64

# %%
x = df.drop(columns=['Price'])
x.columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'Route', 'Dep_Time', 'Arrival_Time',
#        'Duration', 'Total_Stops', 'Additional_Info', 'Month', 'WeekDay',
#        'Day'],
#       dtype='object')

# %% [markdown]
# ## concatination

# %%
d1 ={'name':['shaym'],
     'marks':[10]
     }

# %%
d2 ={'name':['pallavi'],
     'marks':[20]
     }

# %%
df1 = pd.DataFrame(d1)
df2 = pd.DataFrame(d2)
print(df1)
print(df2)
# Out:
#     name  marks
# 0  shaym     10
#       name  marks
# 0  pallavi     20

# %%
df3 = pd.concat([df1 , df2])
df3
# Out:
#       name  marks
# 0    shaym     10
# 0  pallavi     20

# %%
df3.iloc[1]
# Out:
# name     pallavi
# marks         20
# Name: 0, dtype: object
